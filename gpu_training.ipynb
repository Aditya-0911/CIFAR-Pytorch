# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
# !git clone https://github.com/Aditya-0911/CIFAR-Pytorch.git
# %cd CIFAR-Pytorch
# !python main.py
# Out:
# Cloning into 'CIFAR-Pytorch'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 16 (delta 5), reused 14 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (16/16), 5.13 KiB | 5.13 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# /content/CIFAR-Pytorch/CIFAR-Pytorch
# Using device: cuda
# 100% 170M/170M [00:03<00:00, 42.9MB/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# cuda:0
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# Epoch [1/20] - Train Loss: 1.9001, Train Acc: 0.2616 - Val Loss: 1.7546, Val Acc: 0.3278
# Epoch [2/20] - Train Loss: 1.6350, Train Acc: 0.3718 - Val Loss: 1.5185, Val Acc: 0.4278
# Epoch [3/20] - Train Loss: 1.5073, Train Acc: 0.4350 - Val Loss: 1.4401, Val Acc: 0.4524
# Epoch [4/20] - Train Loss: 1.4034, Train Acc: 0.4799 - Val Loss: 1.3059, Val Acc: 0.5202
# Epoch [5/20] - Train Loss: 1.3199, Train Acc: 0.5144 - Val Loss: 1.2590, Val Acc: 0.5324
# Epoch [6/20] - Train Loss: 1.2362, Train Acc: 0.5495 - Val Loss: 1.1712, Val Acc: 0.5786
# Epoch [7/20] - Train Loss: 1.1869, Train Acc: 0.5694 - Val Loss: 1.1087, Val Acc: 0.5950
# Epoch [8/20] - Train Loss: 1.1285, Train Acc: 0.5932 - Val Loss: 1.0913, Val Acc: 0.6054
# Epoch [9/20] - Train Loss: 1.0818, Train Acc: 0.6109 - Val Loss: 1.0672, Val Acc: 0.6108
# Epoch [10/20] - Train Loss: 1.0520, Train Acc: 0.6239 - Val Loss: 0.9811, Val Acc: 0.6434
# Epoch [11/20] - Train Loss: 0.9730, Train Acc: 0.6513 - Val Loss: 0.9383, Val Acc: 0.6608
# Epoch [12/20] - Train Loss: 0.9600, Train Acc: 0.6579 - Val Loss: 0.9327, Val Acc: 0.6656
# Epoch [13/20] - Train Loss: 0.9486, Train Acc: 0.6606 - Val Loss: 0.9292, Val Acc: 0.6626
# Epoch [14/20] - Train Loss: 0.9475, Train Acc: 0.6620 - Val Loss: 0.9217, Val Acc: 0.6656
# Epoch [15/20] - Train Loss: 0.9389, Train Acc: 0.6636 - Val Loss: 0.9165, Val Acc: 0.6654
# Epoch [16/20] - Train Loss: 0.9346, Train Acc: 0.6682 - Val Loss: 0.9144, Val Acc: 0.6670
# Epoch [17/20] - Train Loss: 0.9327, Train Acc: 0.6672 - Val Loss: 0.9124, Val Acc: 0.6682
# Epoch [18/20] - Train Loss: 0.9283, Train Acc: 0.6697 - Val Loss: 0.9053, Val Acc: 0.6746
# Epoch [19/20] - Train Loss: 0.9230, Train Acc: 0.6712 - Val Loss: 0.9047, Val Acc: 0.6716
# Epoch [20/20] - Train Loss: 0.9179, Train Acc: 0.6747 - Val Loss: 0.8967, Val Acc: 0.6714
#
# Test Loss: 0.9040, Test Accuracy: 0.6702
